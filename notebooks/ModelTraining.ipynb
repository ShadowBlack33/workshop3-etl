# %% [markdown]
# # Entrenamiento del Modelo
# Este notebook entrena una regresión lineal y genera `model/happiness_model.pkl` y `data/processed/features_to_stream.csv`.

# %%
from src.train_model import train
train()
